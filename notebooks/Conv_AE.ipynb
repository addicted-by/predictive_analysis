# %% [markdown]
# <a href="https://colab.research.google.com/github/addicted-by/predictive_analysis/blob/main/Conv_AE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipeline for the anomaly detection on the SKAB using Convolutional Autoencoder

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append('../utils')
import os

# %% [markdown]
# ## Data loading

# %%
fi = []
for root, dirs, files in os.walk("/content/SKAB/"):
    for file in files:
        if file.endswith(".csv"):
             fi.append(f'{root}/{file}')

# %%
# !unzip ./drive/MyDrive/vvv/MM/archive.zip

# %%
list_of_df = [pd.read_csv(file, 
                          sep=';', 
                          index_col='datetime', 
                          parse_dates=True) for file in fi if 'anomaly-free' not in file]
anomaly_free_df = pd.read_csv([file for file in fi if 'anomaly-free' in file][0], 
                            sep=';', 
                            index_col='datetime', 
                            parse_dates=True)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Data description and visualization

# %% [markdown]
# ## Labels

# %%
list_of_df[0].anomaly.plot(figsize=(12,3))
list_of_df[0].changepoint.plot()
plt.legend()
plt.show()

# %% [markdown]
# ## Method applying

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import mean_absolute_error, mean_squared_error
from scipy.signal import medfilt
from sklearn import decomposition
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from itertools import product

# %%
def Random(seed_value):
    import os
    os.environ['PYTHONHASHSEED']=str(seed_value)
    import random
    random.seed(seed_value)
    import numpy as np
    np.random.seed(seed_value)
    import tensorflow as tf
    tf.random.set_seed(seed_value)

# %% [markdown]
# ## Метрика F1

# %%
from keras import backend as K

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall
    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## Model

# %%
def arch(data):
    Random(0)
    model = keras.Sequential(
        [
            layers.Input(shape=(data.shape[1], data.shape[2])),
            layers.Conv1D(
                filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
            ),
            layers.Dropout(rate=0.2),
            layers.Conv1D(
                filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
            ),
            layers.Conv1DTranspose(
                filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
            ),
            layers.Dropout(rate=0.2),
            layers.Conv1DTranspose(
                filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
            ),
            layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
        ]
    )
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=5e-4), loss="mse")

    history = model.fit(
        data,
        data,
        epochs=5000,
        batch_size=128,
        validation_split=0.2,
        verbose=1
    )
    return history, model

# %% [markdown]
# ### Training in the beginning of each dataset

# %%
# Generated training sequences for use in the model.
def create_sequences(values, time_steps=N_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)

# %%
type(list_of_df)
# Out:
# list

# %%
N_STEPS = 60
Q = 0.75
from tqdm import tqdm
predicted_outlier, predicted_cp, out = [], [], []
for df in tqdm(list_of_df):
    X_train = df[:400].drop(['anomaly', 'changepoint'], axis=1)
    StSc = StandardScaler()
    StSc.fit(X_train)
    X = create_sequences(StSc.transform(X_train), N_STEPS)
    
    history, model = arch(X)
    out.append(history.history)   
    residuals = pd.Series(np.sum(np.mean(np.abs(X - model.predict(X)), axis=1), axis=1))
    UCL = residuals.quantile(Q)
    
    X = create_sequences(StSc.transform(df.drop(['anomaly','changepoint'], axis=1)), N_STEPS)
    cnn_residuals = pd.Series(np.sum(np.mean(np.abs(X - model.predict(X)), axis=1), axis=1))
    
    anomalous_data = cnn_residuals > (3/2 * UCL)
    anomalous_data_indices = []
    for data_idx in range(N_STEPS - 1, len(X) - N_STEPS + 1):
        if np.all(anomalous_data[data_idx - N_STEPS + 1 : data_idx]):
            anomalous_data_indices.append(data_idx)
    
    prediction = pd.Series(data=0, index=df.index)
    prediction.iloc[anomalous_data_indices] = 1
    
    predicted_outlier.append(prediction)
    
    prediction_cp = abs(prediction.diff())
    prediction_cp[0] = prediction[0]
    predicted_cp.append(prediction_cp)
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6966
# Epoch 2502/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6966
# Epoch 2503/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2504/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2505/5000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2506/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6901 - val_loss: 0.6962
# Epoch 2507/5000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6903 - val_loss: 0.6963
# Epoch 2508/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6901 - val_loss: 0.6964
# Epoch 2509/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6903 - val_loss: 0.6965
# Epoch 2510/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2511/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2512/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2513/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6969
# Epoch 2514/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2515/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6901 - val_loss: 0.6963
# Epoch 2516/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2517/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6903 - val_loss: 0.6966
# Epoch 2518/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2519/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2520/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6903 - val_loss: 0.6962
# Epoch 2521/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2522/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6902 - val_loss: 0.6967
# Epoch 2523/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6965
# Epoch 2524/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6903 - val_loss: 0.6962
# Epoch 2525/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2526/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6901 - val_loss: 0.6967
# Epoch 2527/5000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6902 - val_loss: 0.6968
# Epoch 2528/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2529/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6902 - val_loss: 0.6961
# Epoch 2530/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6903 - val_loss: 0.6965
# Epoch 2531/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6903 - val_loss: 0.6968
# Epoch 2532/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6903 - val_loss: 0.6965
# Epoch 2533/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6904 - val_loss: 0.6962
# Epoch 2534/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6903 - val_loss: 0.6964
# Epoch 2535/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6903 - val_loss: 0.6969
# Epoch 2536/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6967
# Epoch 2537/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6962
# Epoch 2538/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6961
# Epoch 2539/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6901 - val_loss: 0.6965
# Epoch 2540/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6903 - val_loss: 0.6966
# Epoch 2541/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2542/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2543/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6966
# Epoch 2544/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6901 - val_loss: 0.6965
# Epoch 2545/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2546/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6903 - val_loss: 0.6962
# Epoch 2547/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2548/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2549/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6960
# Epoch 2550/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2551/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6902 - val_loss: 0.6967
# Epoch 2552/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2553/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2554/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2555/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2556/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6903 - val_loss: 0.6964
# Epoch 2557/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2558/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2559/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2560/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2561/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2562/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6903 - val_loss: 0.6964
# Epoch 2563/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2564/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2565/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6903 - val_loss: 0.6962
# Epoch 2566/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6903 - val_loss: 0.6967
# Epoch 2567/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6968
# Epoch 2568/5000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6901 - val_loss: 0.6962
# Epoch 2569/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6960
# Epoch 2570/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2571/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2572/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2573/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2574/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2575/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6967
# Epoch 2576/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2577/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6901 - val_loss: 0.6962
# Epoch 2578/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2579/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2580/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6903 - val_loss: 0.6966
# Epoch 2581/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2582/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6959
# Epoch 2583/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6902 - val_loss: 0.6960
# Epoch 2584/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2585/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6903 - val_loss: 0.6966
# Epoch 2586/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2587/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2588/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2589/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2590/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2591/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2592/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2593/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2594/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2595/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2596/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2597/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2598/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2599/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2600/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2601/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2602/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2603/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2604/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6964
# Epoch 2605/5000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2606/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2607/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6901 - val_loss: 0.6964
# Epoch 2608/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2609/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2610/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2611/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2612/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6961
# Epoch 2613/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6965
# Epoch 2614/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6903 - val_loss: 0.6966
# Epoch 2615/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2616/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2617/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2618/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6901 - val_loss: 0.6965
# Epoch 2619/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2620/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2621/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2622/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6903 - val_loss: 0.6964
# Epoch 2623/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6901 - val_loss: 0.6961
# Epoch 2624/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6903 - val_loss: 0.6964
# Epoch 2625/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2626/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2627/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2628/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2629/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6967
# Epoch 2630/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6903 - val_loss: 0.6963
# Epoch 2631/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2632/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6901 - val_loss: 0.6966
# Epoch 2633/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6966
# Epoch 2634/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6901 - val_loss: 0.6962
# Epoch 2635/5000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6901 - val_loss: 0.6962
# Epoch 2636/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6965
# Epoch 2637/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6964
# Epoch 2638/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2639/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2640/5000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6903 - val_loss: 0.6967
# Epoch 2641/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6963
# Epoch 2642/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6961
# Epoch 2643/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6903 - val_loss: 0.6965
# Epoch 2644/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6901 - val_loss: 0.6967
# Epoch 2645/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6902 - val_loss: 0.6961
# Epoch 2646/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6902 - val_loss: 0.6961
# Epoch 2647/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6901 - val_loss: 0.6967
# Epoch 2648/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - val_loss: 0.6969
# Epoch 2649/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6902 - val_loss: 0.6962
# Epoch 2650/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.
5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8995 - val_loss: 0.7823
# Epoch 4747/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8995 - val_loss: 0.7820
# Epoch 4748/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4749/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8994 - val_loss: 0.7821
# Epoch 4750/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7825
# Epoch 4751/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4752/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8994 - val_loss: 0.7819
# Epoch 4753/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8995 - val_loss: 0.7820
# Epoch 4754/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7825
# Epoch 4755/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4756/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7821
# Epoch 4757/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8993 - val_loss: 0.7825
# Epoch 4758/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7825
# Epoch 4759/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4760/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7820
# Epoch 4761/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4762/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7821
# Epoch 4763/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4764/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8993 - val_loss: 0.7821
# Epoch 4765/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4766/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8993 - val_loss: 0.7821
# Epoch 4767/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8993 - val_loss: 0.7826
# Epoch 4768/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8993 - val_loss: 0.7826
# Epoch 4769/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8994 - val_loss: 0.7827
# Epoch 4770/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7824
# Epoch 4771/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8993 - val_loss: 0.7826
# Epoch 4772/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4773/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8992 - val_loss: 0.7824
# Epoch 4774/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7820
# Epoch 4775/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4776/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4777/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7825
# Epoch 4778/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8993 - val_loss: 0.7820
# Epoch 4779/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7826
# Epoch 4780/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7825
# Epoch 4781/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7824
# Epoch 4782/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.8994 - val_loss: 0.7821
# Epoch 4783/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8995 - val_loss: 0.7824
# Epoch 4784/5000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.8993 - val_loss: 0.7827
# Epoch 4785/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4786/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4787/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7825
# Epoch 4788/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8994 - val_loss: 0.7825
# Epoch 4789/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4790/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8995 - val_loss: 0.7820
# Epoch 4791/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8993 - val_loss: 0.7823
# Epoch 4792/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4793/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4794/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7825
# Epoch 4795/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4796/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4797/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7820
# Epoch 4798/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7824
# Epoch 4799/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4800/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8995 - val_loss: 0.7825
# Epoch 4801/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7820
# Epoch 4802/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7824
# Epoch 4803/5000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4804/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4805/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4806/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4807/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8993 - val_loss: 0.7823
# Epoch 4808/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8993 - val_loss: 0.7821
# Epoch 4809/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8992 - val_loss: 0.7821
# Epoch 4810/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4811/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8993 - val_loss: 0.7821
# Epoch 4812/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.8993 - val_loss: 0.7820
# Epoch 4813/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4814/5000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8994 - val_loss: 0.7821
# Epoch 4815/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8993 - val_loss: 0.7822
# Epoch 4816/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7820
# Epoch 4817/5000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8994 - val_loss: 0.7820
# Epoch 4818/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8993 - val_loss: 0.7821
# Epoch 4819/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8995 - val_loss: 0.7821
# Epoch 4820/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7821
# Epoch 4821/5000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8993 - val_loss: 0.7823
# Epoch 4822/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4823/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8993 - val_loss: 0.7821
# Epoch 4824/5000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8993 - val_loss: 0.7819
# Epoch 4825/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8994 - val_loss: 0.7823
# Epoch 4826/5000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8992 - val_loss: 0.7824
# Epoch 4827/5000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8994 - val_loss: 0.7822
# Epoch 4828/5000
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9053

# %% [markdown]
# ### Results

# %% [markdown]
# ## Metrics calculation

# %%
import pandas as pd
import numpy as np

def evaluating_change_point(true, prediction, metric='nab', numenta_time=None):
    """
    true - both:
                list of pandas Series with binary int labels
                pandas Series with binary int labels
    prediction - both:
                      list of pandas Series with binary int labels
                      pandas Series with binary int labels
    metric: 'nab', 'binary' (FAR, MAR), 'average_delay'
                
    """
    
    def binary(true, prediction):      
        """
        true - true binary series with 1 as anomalies
        prediction - trupredicted binary series with 1 as anomalies
        """
        def single_binary(true,prediction):
            true_ = true == 1 
            prediction_ = prediction == 1
            TP = (true_ & prediction_).sum()
            TN = (~true_ & ~prediction_).sum()
            FP = (~true_ & prediction_).sum()
            FN = (true_ & ~prediction_).sum()
            return TP,TN,FP,FN
            
        if type(true) != type(list()):
            TP,TN,FP,FN = single_binary(true,prediction)
        else:
            TP,TN,FP,FN = 0,0,0,0
            for i in range(len(true)):
                TP_,TN_,FP_,FN_ = single_binary(true[i],prediction[i])
                TP,TN,FP,FN = TP+TP_,TN+TN_,FP+FP_,FN+FN_       
    
        f1 = round(TP/(TP+(FN+FP)/2), 2)
        print(f'False Alarm Rate {round(FP/(FP+TN)*100,2)} %' )
        print(f'Missing Alarm Rate {round(FN/(FN+TP)*100,2)} %')
        print(f'F1 metric {f1}')
        return f1
    
    def average_delay(detecting_boundaries, prediction):
        
        def single_average_delay(detecting_boundaries, prediction):
            missing = 0
            detectHistory = []
            for couple in detecting_boundaries:
                t1 = couple[0]
                t2 = couple[1]
                if prediction[t1:t2].sum()==0:
                    missing+=1
                else:
                    detectHistory.append(prediction[prediction ==1][t1:t2].index[0]-t1)
            return missing, detectHistory
            
        
        if type(prediction) != type(list()):
            missing, detectHistory = single_average_delay(detecting_boundaries, prediction)
        else:
            missing, detectHistory = 0, []
            for i in range(len(prediction)):
                missing_, detectHistory_ = single_average_delay(detecting_boundaries[i], prediction[i])
                missing, detectHistory = missing+missing_, detectHistory+detectHistory_

        add = pd.Series(detectHistory).mean()
        print('Average delay', add)
        print(f'A number of missed CPs = {missing}')
        return add
    
    def evaluate_nab(detecting_boundaries, prediction, table_of_coef=None):
        """
        Scoring labeled time series by means of
        Numenta Anomaly Benchmark methodics
        Parameters
        ----------
        detecting_boundaries: list of list of two float values
            The list of lists of left and right boundary indices
            for scoring results of labeling
        prediction: pd.Series with timestamp indices, in which 1 
            is change point, and 0 in other case. 
        table_of_coef: pandas array (3x4) of float values
            Table of coefficients for NAB score function
            indeces: 'Standart','LowFP','LowFN'
            columns:'A_tp','A_fp','A_tn','A_fn'
        Returns
        -------
        Scores: numpy array, shape of 3, float
            Score for 'Standart','LowFP','LowFN' profile 
        Scores_null: numpy array, shape 3, float
            Null score for 'Standart','LowFP','LowFN' profile             
        Scores_perfect: numpy array, shape 3, float
            Perfect Score for 'Standart','LowFP','LowFN' profile  
        """
        def single_evaluate_nab(detecting_boundaries, prediction, table_of_coef=None, name_of_dataset=None):
            if table_of_coef is None:
                table_of_coef = pd.DataFrame([[1.0,-0.11,1.0,-1.0],
                                     [1.0,-0.22,1.0,-1.0],
                                      [1.0,-0.11,1.0,-2.0]])
                table_of_coef.index = ['Standart','LowFP','LowFN']
                table_of_coef.index.name = "Metric"
                table_of_coef.columns = ['A_tp','A_fp','A_tn','A_fn']

            alist = detecting_boundaries.copy()
            prediction = prediction.copy()

            Scores, Scores_perfect, Scores_null=[], [], []
            for profile in ['Standart', 'LowFP', 'LowFN']:       
                A_tp = table_of_coef['A_tp'][profile]
                A_fp = table_of_coef['A_fp'][profile]
                A_fn = table_of_coef['A_fn'][profile]
                def sigm_scale(y, A_tp, A_fp, window=1):
                    return (A_tp-A_fp)*(1/(1+np.exp(5*y/window))) + A_fp

                #First part
                score = 0
                if len(alist)>0:
                    score += prediction[:alist[0][0]].sum()*A_fp
                else:
                    score += prediction.sum()*A_fp
                #second part
                for i in range(len(alist)):
                    if i<=len(alist)-2:
                        win_space = prediction[alist[i][0]:alist[i+1][0]].copy()
                    else:
                        win_space = prediction[alist[i][0]:].copy()
                    win_fault = prediction[alist[i][0]:alist[i][1]]
                    slow_width = int(len(win_fault)/4)

                    if len(win_fault) + slow_width >= len(win_space):
                        print(f'Intersection of the windows of too wide widths for dataset {name_of_dataset}')
                        win_fault_slow = win_fault.copy()
                    else:
                        win_fault_slow= win_space[:len(win_fault)  +  slow_width]

                    win_fp = win_space[-len(win_fault_slow):]

                    if win_fault_slow.sum() == 0:
                        score+=A_fn
                    else:
                        #to get the first index
                        tr = pd.Series(win_fault_slow.values,index = range(-len(win_fault), len(win_fault_slow)-len(win_fault)))
                        tr_values= tr[tr==1].index[0]
                        tr_score = sigm_scale(tr_values, A_tp,A_fp,slow_width)
                        score += tr_score
                        score += win_fp.sum()*A_fp
                Scores.append(score)
                Scores_perfect.append(len(alist)*A_tp)
                Scores_null.append(len(alist)*A_fn)
            return np.array([np.array(Scores),np.array(Scores_null), np.array(Scores_perfect)])
       #======      
        if type(prediction) != type(list()):
            matrix = single_evaluate_nab(detecting_boundaries, prediction, table_of_coef=table_of_coef)
        else:
            matrix = np.zeros((3,3))
            for i in range(len(prediction)):
                matrix_ = single_evaluate_nab(detecting_boundaries[i], prediction[i], table_of_coef=table_of_coef,name_of_dataset=i)
                matrix = matrix + matrix_      
                
        results = {}
        desc = ['Standart', 'LowFP', 'LowFN'] 
        for t, profile_name in enumerate(desc):
            results[profile_name] = round(100*(matrix[0,t]-matrix[1,t])/(matrix[2,t]-matrix[1,t]), 2)
            print(profile_name,' - ', results[profile_name])
        
        return results
            
            
    #=========================================================================
    if type(true) != type(list()):
        true_items = true[true==1].index
    else:
        true_items = [true[i][true[i]==1].index for i in range(len(true))]
        

    if not metric=='binary':
        def single_detecting_boundaries(true, numenta_time, true_items):
            detecting_boundaries=[]
            td = pd.Timedelta(numenta_time) if numenta_time is not None else pd.Timedelta((true.index[-1]-true.index[0])/len(true_items))  
            for val in true_items:
                detecting_boundaries.append([val, val + td])
            return detecting_boundaries
        
        if type(true) != type(list()):
            detecting_boundaries = single_detecting_boundaries(true=true, numenta_time=numenta_time, true_items=true_items)
        else:
            detecting_boundaries=[]
            for i in range(len(true)):
                detecting_boundaries.append(single_detecting_boundaries(true=true[i], numenta_time=numenta_time, true_items=true_items[i]))

    if metric== 'nab':
        return evaluate_nab(detecting_boundaries, prediction)
    elif metric=='average_delay':
        return average_delay(detecting_boundaries, prediction)
    elif metric== 'binary':
        return binary(true, prediction)

# %%
plt.plot(history.history['val_loss'], label='val', color='blue')
plt.plot(history.history['loss'], label='train', color='red')

# %%
true_outlier = [df.anomaly for df in list_of_df]
predicted_outlier[1].plot(figsize=(12, 3), label='predictions', marker='o', markersize=5)
true_outlier[1].plot(marker='o', markersize=2)
plt.legend();

# %%
true_cp = [df.changepoint for df in list_of_df]
predicted_cp[1].plot(figsize=(12, 3), label='predictions', marker='o', markersize=7)
true_cp[1].plot(marker='o', markersize=4)
plt.legend();

# %% [markdown]
# ## coding

# %%
binary = evaluating_change_point(true_outlier, predicted_outlier, metric='binary', numenta_time='60 sec')
# Out:
# False Alarm Rate 7.48 %
# Missing Alarm Rate 30.92 %
# F1 metric 0.76

# %% [markdown]
# ## ClearML

# %%
true_outlier = [df.anomaly for df in list_of_df]
predicted_outlier[1].plot(figsize=(12, 3), label='predictions', marker='o', markersize=5)
true_outlier[1].plot(marker='o', markersize=2)
plt.legend();

# %%
binary = evaluating_change_point(true_outlier, predicted_outlier, metric='binary', numenta_time='60 sec')
# Out:
# False Alarm Rate 7.7 %
# Missing Alarm Rate 31.24 %
# F1 metric 0.75
